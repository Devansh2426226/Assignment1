# %% [markdown]
# <a href="https://colab.research.google.com/github/Devansh2426226/Assignment1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %%
a=10;

# %%
b=40

# %%
type(b)
# Out:
# int

# %%
y=9.7

# %%
type(y)
# Out:
# float

# %%
print("hello SRMCEM")
# Out:
# hello SRMCEM

# %%
s="SRMCEM"

# %%
s[0:3:-5]
# Out:
# ''

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_2415/2794436645.py in <cell line: 0>()
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
False/True
# Out:
# 0.0

# %%
S="TRUE"

# %%
print(S)
# Out:
# TRUE

# %%
t="Batch name is Computer Science & Engineering"

# %%
t[0:16:7]
# Out:
# 'BaC'

# %%
t[0:16:90]
# Out:
# 'B'

# %%
t[-3:-44:-5]
# Out:
# 'ii&ermina'

# %%
l=["deepali.",9.1,"certificateproducer",8.96,4+3j]

# %%
l[4].real
# Out:
# 4.0

# %%
l[4].imag
# Out:
# 3.0

# %%
type(l)
# Out:
# list

# %%
type(l[4])
# Out:
# complex

# %%
d="Ramswar  oop"

# %%
d.count('o')
# Out:
# 2

# %%
d.count('')
# Out:
# 13

# %%
d.find('s')
# Out:
# 3

# %%
d.lower()
# Out:
# 'ramswar  oop'

# %%
d.upper()
# Out:
# 'RAMSWAR  OOP'

# %%
len(d)
# Out:
# 12

# %%
l[::-1]
# Out:
# [570, 'certificateproducer', 9.1, 'deepali.', 56]

# %%
d[::-1]
# Out:
# 'poo  rawsmaR'

# %%
l.append(67)

# %%
l.pop()
# Out:
# 67

# %%
l.pop()
# Out:
# 8.96

# %%
l.insert(0,56)

# %%
print(l)
# Out:
# [56, 'deepali.', 9.1, 'certificateproducer']

# %%
l.insert(4,570)

# %%
print(l)
# Out:
# [56, 'deepali.', 9.1, 'certificateproducer', 570]

# %%
r=(24,"shyam","it",23,"supercalifrajilisticexpilodicious",54,76,840)

# %%
r[0:7:1]
# Out:
# (24, 'shyam', 'it', 23, 'supercalifrajilisticexpilodicious', 54, 76)

# %%
r.count(24)
# Out:
# 1

# %%
len(r[4])
# Out:
# 33

# %%
dict={"name":'age',"Ramesh":89,"Mushkaan":23}

# %%
dict["name"]
# Out:
# 'age'

# %%
dict['Ramesh']
# Out:
# 89

# %%
len(dict)
# Out:
# 3

# %%
l=["ram","rahul",43,65,76]

# %%
len(l)
# Out:
# 5

# %%
l.remove(43)

# %%
print(l)
# Out:
# ['ram', 'rahul', 43, 65, 76]

# %%
marks=34
if marks>89:
  print("pass")
elif marks>70:
  print("distinction")
else:
  print("fail")
# Out:
# fail

# %%
x=int(input())
if x>90:
  print("a+")
elif 80<x<90:
  print("a")
elif 70<x<79:
  print("b+")
elif 60<x<69:
  print("b")
else :
  print("f")
# Out:
# 94
# a+

# %%
menu={
    "Cold Tea":90,
    "Black coffe":50,
    "lemonade":60,
    "Hot coffe":70,
}
print("Welcome to my res......")
print(menu)
order_total = 0

item_1 = input("Enter the name of item you want to order = ")

if item_1 in menu:
    order_total += menu[item_1]
    print(f"Your item {item_1} has been added to your order")
else:
    print(f"Ordered item {item_1} is not available yet!!")

another_order = input("Do you want to add another item? (Yes/No) ")

if another_order == "Yes":
    item_2 = input("Enter the name of second item = ")

    if item_2 in menu:
        order_total += menu[item_2]
        print(f"Item {item_2} has been added to order")
    else:
        print(f"Ordered {item_2} is not available")

print(f"The total amount of items to pay is {order_total}")
# Out:
# Welcome to my res......
# {'Cold Tea': 90, 'Black coffe': 50, 'lemonade': 60, 'Hot coffe': 70}
# Enter the name of item you want to order = tea
# Ordered item tea is not available yet!!
# Do you want to add another item? (Yes/No) yes
# The total amount of items to pay is 0
# Welcome to my res......
# {'Cold Tea': 90, 'Black coffe': 50, 'lemonade': 60, 'Hot coffe': 70}
# Enter the name of item you want to order = Hot coffe
# Your item Hot coffe has been added to your order
# Do you want to add another item? (Yes/No) no
# The total amount of items to pay is 70

# %%
lab={
    "ramesh":60,
    "suresh":40,
    "ram":50,
    "shyam":90,
}
for keys in lab:
  print(f"Key: {keys}, Value: {lab[keys]}")
# Out:
# Key: ramesh, Value: 60
# Key: suresh, Value: 40
# Key: ram, Value: 50
# Key: shyam, Value: 90

# %%
# Out:
# ramesh
# suresh
# ram
# shyam
